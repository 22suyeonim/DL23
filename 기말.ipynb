# %% [markdown]
# <a href="https://colab.research.google.com/github/22suyeonim/DL23/blob/main/%EA%B8%B0%EB%A7%90.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **word cloud**

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

user_text = input("Please paste your text here: ")


wordcloud = WordCloud(
    background_color='white',
    width=800,
    height=800,
    max_words=100
).generate(user_text)

plt.figure(figsize=(8, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# Please paste your text here: fihgt

# %% [markdown]
# # **tts**

# %%
# %%capture
# !pip install gTTS
from gtts import gTTS
from IPython.display import Audio

def tts(text):
  gtts_object = gTTS(text,lang = "en", slow = True) 
  gtts_object.save("myaudio.mp3")
  return Audio("myaudio.mp3")

# %%
#이렇게 제시어를 줘야지 말로바꿔줌
tts('Hello students')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# 만약 텍스트 넣으면 tts가 재생이 되도록 하고싶다 하면 밑에꺼
#
#
# **setup gtts for speech**

# %%
  # %%capture
# !pip install gtts
from gtts import gTTS
from IPython.display import Audio, display

# %%
def tts(txt):
  tts = gTTS(txt, lang='en')
  tts.save("sample.mp3")
  return Audio("/content/sample.mp3")

# %%
mytext = input("Type text: ")
tts(mytext)
# Out:
# Type text: hi
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # **기말꺼**
# NLP1
#
#
# *  Tokenize by words or sentences
#
# *   Filtering stopwords
#
#
# *   Tagging Parts of Speech
#
#
#
# NLP2
#
#
# *   import nltk
#
# *   getting word frequency(lower, stop ward to remove
# *   word list
#
#
# *
# write a csv file
#
#
# DLW13A
#
#
# *   gradio(d-day, tts, 성적체크)
#
#
# DLW14
# 왕이야기 유튜브
#
#
# *   왕이야기 유튜브
# *   SST (Speech-to-Text) using Whisper (OpenAI)-대본 번역한거

# %% [markdown]
# # **중간꺼**
# DLW02a
#
# *   Expanding tts: ktts, etts, ftts
#
# DLW02b
#
#
# *   variable(변수)
# *   commenting #
#
#
# *   operator: +-등등
# *   항목 추가
#
#
# DLW02c
#
#
# *   한국시간 런던시간 이런
#
# DLW02d
#
#
# *  함수, 코딩 계산하는 거 나옴
#
# *   Input types:
# integer: e.g., -3, 1, 0, 234, etc/
# float: e.g., -3.0, 1.2, 0, 3.141592653589793238, etc/
# string: (characters) "1", '0', "3.29", "Mary", "euphoria", 'My name is Jane.'
#
#
# DLW04a
#
#
# *   달리 지피티 같은 도구 소개
#
# DLW05A
# *   위에꺼랑 내용 같음
#
#
# DL06A_P1
#
#
# *   단어 퀴즈 만드는
# *   YES NO 질문
#
#
# *   story game
#
#
# *   strip split lower string integer list등등 나옴
#
# DL06A_PART 2
# *   for loops
